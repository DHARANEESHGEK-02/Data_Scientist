# %% [markdown]
# Predicting the house price using schkit learn

# %%
import numpy as np
from sklearn.metrics import r2_score ,mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression

model=LinearRegression()
x=np.array([[1000],[2000],[3000],[4000]])
y=np.array([[100],[200],[300],[400]])

model.fit(x,y)
y_pred=model.predict(x)

print("R2 Score:", r2_score(y,y_pred))
print("Mean Absolute Error:", mean_absolute_error(y,y_pred))
print("Mean Squared Error:", mean_squared_error(y,y_pred)) 
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y,y_pred)))
# Out:
# R2 Score: 1.0
# Mean Absolute Error: 3.552713678800501e-15
# Mean Squared Error: 5.048709793414476e-29
# Root Mean Squared Error: 7.105427357601002e-15
