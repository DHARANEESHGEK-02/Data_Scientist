# %%
import numpy as np

# %%
arr=np.array([1,2,3])
arr
# Out:
# array([1, 2, 3])

# %%
arr.reshape(3,1)
arr
# Out:
# array([1, 2, 3])

# %%
arr.mean()
# Out:
# np.float64(2.0)

# %%
arr.std()
# Out:
# np.float64(0.816496580927726)

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
reshaped = arr.reshape(5,1)
print("arr.reshape(5,1):\n", reshaped)
# Out:
# arr.reshape(5,1):
#  [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
