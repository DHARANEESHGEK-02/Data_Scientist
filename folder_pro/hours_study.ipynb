# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
hours=np.array([[1],[2],[3],[4],[5]])
marks=np.array([35,40,45,50,60])
print("Input hours:",hours)
print("Target marks:",marks)
# Out:
# Input hours: [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
# Target marks: [35 40 45 50 60]

# %%
model=LinearRegression()
model.fit(hours,marks)
# Out:
# LinearRegression()

# %%
predicted_6=model.predict([[6]])
print("Predicted marks for 6 hours study:",prdictes_6[0])
# Out:
# Predicted marks for 6 hours study: 64.0

# %%
predicted_train=model.predict(hours)
print("Predicted marks for training data:",predict_train)
# Out:
# Predicted marks for training data: [34. 40. 46. 52. 58.]

# %%
# Step 6: Plot the data and regression line
plt.figure(figsize=(8, 5))
plt.scatter(hours, marks, color='blue', label='Actual Marks')
plt.plot(hours, predicted_train, color='red', label='Regression Line')
plt.scatter(6, predicted_6, color='green', label='Prediction for 6 hrs', marker='*', s=100)
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
plt.title("Linear Regression - Hours vs Marks")
plt.legend()
plt.grid(True)
plt.show()
