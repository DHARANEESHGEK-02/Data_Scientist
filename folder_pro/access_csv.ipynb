# %% [markdown]
# Reading a csv file

# %%
import csv


with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    header = next(reader) 
    for row in reader:
        print(row)
# Out:
# ['Alice', '20', '85', '92', '78', '85.0']
# ['Bob', '21', '76', '82', '89', '82.3']
# ['Charlie', '19', '92', '88', '95', '91.7']
# ['Diana', '22', '68', '75', '82', '75.0']
# ['Eve', '20', '94', '91', '87', '90.7']
# ['Frank', '21', '82', '79', '85', '82.0']

# %%
with open('data.csv', 'r') as file:
    reader = csv.reader(file)
    header = next(reader) 
    for row in reader:
        print(row)
# Out:
# ['Alice', '25']

# %%
import csv
with open('data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age','Math','Science','English','Average'])  # Header
    writer.writerow(['Henry', 25,23,76,89,62.7])
