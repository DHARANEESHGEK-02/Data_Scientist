# %%
value=(int(input("Enter the values:")) for _ in range(5))
my_tuple=list(value)
print("My list:",set(my_tuple))
# Out:
# My list: {1}

# %% [markdown]
# Intializing  the dictionary (User Input)

# %%
student={}
n=int(input("Enter how many values"))
for i in range(n):
    key=input("Enter the key:")
    value=input("Enter the values:")
    student[key]=value
student

# %% [markdown]
# Intializing list user-input

# %%
n=int(input("Enter how many values"))
values=(int(input("Enter the values:")) for _ in range(n))
my_list=list(values)    
my_list
