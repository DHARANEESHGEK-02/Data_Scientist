# %% [markdown]
# Using StandardScaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# Sample data
X = np.array([[1, 1000], [2, 2000], [3, 3000], [4, 4000]])
y = np.array([0, 1, 0, 1])

# Step 1: Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Step 2: Fit scaler ONLY on TRAIN data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)  # Fit + transform train

# Step 3: Transform test data (NO fit!)
X_test_scaled = scaler.transform(X_test)        # Only transform test

print("Train scaled:\n", X_train_scaled)  # mean=0, std=1
print("Test scaled:\n", X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/sklearn/__check_build/__init__.py:45
#      44 try:
# ---> 45     from ._check_build import check_build  # noqa
#      46 except ImportError as e:
#
# ModuleNotFoundError: No module named 'sklearn.__check_build._check_build'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 from sklearn.preprocessing import StandardScaler
#       3 import numpy as np
#
# File /usr/lib/python3/dist-packages/sklearn/__init__.py:83
#      72     sys.stderr.write("Partial import of sklearn during the build process.\n")
#      73     # We are not importing the rest of scikit-learn during the build
#      74     # process, as it may not be compiled yet
#      75 else:
#    (...)
#      81     # later is linked to the OpenMP runtime to make it possible to introspect
#      82     # it and importing it first would fail if the OpenMP dll cannot be found.
# ---> 83     from . import (
#      84         __check_build,  # noqa: F401
#      85         _distributor_init,  # noqa: F401
#      86     )
#      87     from .base import clone
#      88     from .utils._show_versions import show_versions
#
# File /usr/lib/python3/dist-packages/sklearn/__check_build/__init__.py:47
#      45     from ._check_build import check_build  # noqa
#      46 except ImportError as e:
# ---> 47     raise_build_error(e)
#
# File /usr/lib/python3/dist-packages/sklearn/__check_build/__init__.py:31, in raise_build_error(e)
#      29         else:
#      30             dir_content.append(filename + "\n")
# ---> 31     raise ImportError("""%s
#      32 ___________________________________________________________________________
#      33 Contents of %s:
#      34 %s
#      35 ___________________________________________________________________________
#      36 It seems that scikit-learn has not been built correctly.
#      37
#      38 If you have installed scikit-learn from source, please do not forget
#      39 to build the package before using it: run `python setup.py install` or
#      40 `make` in the source directory.
#      41 %s""" % (e, local_dir, "".join(dir_content).strip(), msg))
#
# ImportError: No module named 'sklearn.__check_build._check_build'
# ___________________________________________________________________________
# Contents of /usr/lib/python3/dist-packages/sklearn/__check_build:
# _check_build.cpython-312-x86_64-linux-gnu.so__init__.py               __pycache__
# ___________________________________________________________________________
# It seems that scikit-learn has not been built correctly.
#
# If you have installed scikit-learn from source, please do not forget
# to build the package before using it: run `python setup.py install` or
# `make` in the source directory.
#
# If you have used an installer, please check that it is suited for your
# Python version, your operating system and your platform.
